# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
jan2020 = pd.read_csv("./datasets/State of California- Vehicle Fuel Type Count by ZIP Code JANUARY 2020.csv")
# Out:
# C:\Users\akhi\AppData\Local\Temp\ipykernel_240\3356154423.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan2020 = pd.read_csv("./datasets/State of California- Vehicle Fuel Type Count by ZIP Code JANUARY 2020.csv")

# %%
jan2021 = pd.read_csv("./datasets/State of California- Vehicle Fuel Type Count by ZIP Code JANUARY 2021.csv")

jan2022 = pd.read_csv("./datasets/State of California- Vehicle Fuel Type Count by ZIP Code JANUARY 2022.csv")
jan2023 = pd.read_csv("./datasets/State of California- Vehicle Fuel Type Count by ZIP Code JANUARY 2023.csv")
jan2018 = pd.read_csv("./datasets/State of California- Vehicle Fuel Type Count by ZIP Code OCTOBER 2018.csv")
# Out:
# C:\Users\akhi\AppData\Local\Temp\ipykernel_240\3110769524.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan2021 = pd.read_csv("./datasets/State of California- Vehicle Fuel Type Count by ZIP Code JANUARY 2021.csv")
# C:\Users\akhi\AppData\Local\Temp\ipykernel_240\3110769524.py:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan2022 = pd.read_csv("./datasets/State of California- Vehicle Fuel Type Count by ZIP Code JANUARY 2022.csv")
# C:\Users\akhi\AppData\Local\Temp\ipykernel_240\3110769524.py:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan2023 = pd.read_csv("./datasets/State of California- Vehicle Fuel Type Count by ZIP Code JANUARY 2023.csv")
# C:\Users\akhi\AppData\Local\Temp\ipykernel_240\3110769524.py:5: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan2018 = pd.read_csv("./datasets/State of California- Vehicle Fuel Type Count by ZIP Code OCTOBER 2018.csv")

# %%
def change_index(series):
    series.index = pd.to_datetime(series.index)
    series = series.sort_index()
    return series

total = pd.concat([jan2018, jan2020, jan2021, jan2022, jan2023])

total = total.groupby(by = ["Fuel", "Date"]).Vehicles.sum()
bat_ele = total["Battery Electric"]
gas = total["Gasoline"]
hyb = total["Hybrid Gasoline"]

bat_ele = change_index(bat_ele)
gas = change_index(gas)
hyb = change_index(hyb)

fig = plt.figure(figsize=(6,5))
plt.xticks(rotation=45)
sns.lineplot(data=gas, color='red')

plt.figure(figsize=(6,5))
plt.xticks(rotation=45)
sns.lineplot(data=bat_ele, color='green')
# Out:
# <Axes: xlabel='Date', ylabel='Vehicles'>

# %%
sns.barplot(data = gas, color="red")
plt.figure(figsize = (16,6))
plt.title("Battery Electric")
sns.barplot(data = bat_ele)
# Out:
# <Axes: title={'center': 'Battery Electric'}, xlabel='Date', ylabel='Vehicles'>

# %%
### Current Market #######

def show_current_market(df):

    plt.figure(figsize = (10,20))
    plt.xticks(rotation=45)
    groups = df.groupby("Fuel").Vehicles.sum().loc["Battery Electric":"Hybrid Gasoline"]
    
    
    g = sns.barplot(data = groups)

    g.bar_label(g.containers[0], label_type='edge')
    return g

show_current_market(jan2020)

show_current_market(jan2021)
# Out:
# <Axes: xlabel='Fuel', ylabel='Vehicles'>

# %%
######## Top companies (makes) #################

total = pd.concat([jan2018, jan2020, jan2021, jan2022, jan2023])

top_makes = total.groupby("Make").Vehicles.sum().sort_values(ascending=False)

top_makes = top_makes[top_makes.index != "OTHER/UNK"]


top_makes["TESLA"]
# Look at Heavy and light duty relationships
# Out:
# 1551105

# %% [markdown]
# <b> Look like Toyota, Honda, and Ford are the top companies </b>

# %% [markdown]
# <b> Lets look at a electric car company. Example would be tesla! </b>

# %%
based_company = total.groupby(by = ["Make", "Fuel", "Date"]).Vehicles.sum()

tesla = based_company.loc["HONDA"].reset_index()
tesla.Date = pd.to_datetime(tesla.Date)
tesla = tesla.set_index("Date").sort_index()
tesla  = tesla.loc[tesla.Fuel.isin(["Battery Electric", "Gasoline"])]
sns.lineplot(x = tesla.index, y = tesla.Vehicles, hue=tesla.Fuel)
plt.xticks(rotation=60)
# Out:
# (array([17897., 18078., 18262., 18444., 18628., 18809., 18993., 19174.,
#         19358.]),
#  [Text(17897.0, 0, '2019-01'),
#   Text(18078.0, 0, '2019-07'),
#   Text(18262.0, 0, '2020-01'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19174.0, 0, '2022-07'),
#   Text(19358.0, 0, '2023-01')])

# %% [markdown]
# <p>
#     As you can see, the big companies are barely looking at battery electric cars. They have not growth, and only have growth in gasoline cars. But relatively new company like Tesla are seeing big growth in battery electric cars. This shows that as a new company, we might have a place in the market for battery electric cars. Being bombarded by big companies in the gasoline market wouldn't give us leverage on the market.
# </p>

# %%
based_company = total.groupby(by = ["Make", "Fuel", "Date"]).Vehicles.sum()

tesla = based_company.loc["TESLA"].reset_index()
tesla.Date = pd.to_datetime(tesla.Date)
tesla = tesla.set_index("Date").sort_index()
tesla  = tesla.loc[tesla.Fuel.isin(["Battery Electric", "Gasoline"])]
sns.lineplot(x = tesla.index, y = tesla.Vehicles, hue=tesla.Fuel)
plt.xticks(rotation=60)
# Out:
# (array([17897., 18078., 18262., 18444., 18628., 18809., 18993., 19174.,
#         19358.]),
#  [Text(17897.0, 0, '2019-01'),
#   Text(18078.0, 0, '2019-07'),
#   Text(18262.0, 0, '2020-01'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19174.0, 0, '2022-07'),
#   Text(19358.0, 0, '2023-01')])

# %% [markdown]
# <b> As you can see, the growth of Tesla's electric cars more have gone up more than 1000% </b>

# %% [raw]
# Note: Relate this to the global electric car market's rise at the top
